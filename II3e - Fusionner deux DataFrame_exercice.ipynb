# %% [markdown]
# # Fusionner deux DataFrame
#
# Dans le cours précédent, on a créé deux DataFrames à partir des fichiers `country_gdp_per_capita.csv` et `metadata_country.xlsx`. Le premier regroupe le PIBs par habitant par pays, le second classe les pays par régions et par groupes.
#
# Nous allons fusionner ces DataFrames pour associer les pays, les PIBs, les régions et les groupes.

# %% [markdown]
# ## Import de la librairie pandas

# %%
#import pandas

# %% [markdown]
# ## transformer les fichiers en DataFrame

# %%
# transformer le fichier .csv en DataFrame, séprarateur ; et décimal ,

# %%
# transformer le fichier .xlsx en DataFrame

# %% [markdown]
# ## Fusionner des DataFrames

# %% [markdown]
# Les deux DataFrames ont une colonne en commun `Country Code`, la fusion des est réalisée sur cette colonne.

# %% [markdown]
# ### Jointure interne inner
# La jointure interne `inner` est l'intersection de deux ensembles.
#
# On récupère uniquement les informations en commun du DataFrame de gauche et de droite.
#
# ![image.png](attachment:image.png)
#
# Dans notre cas, on obtient un DataFrame avec les `Country Code` présents à la fois dans le DataFrame des PIBs et le DataFrame des metadonnées.

# %%
# jointure inner
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 247                        Samoa          WSM  GDP per capita (current US$)
# 248                       Kosovo          XKX  GDP per capita (current US$)
# 249                 South Africa          ZAF  GDP per capita (current US$)
# 250                       Zambia          ZMB  GDP per capita (current US$)
# 251                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %% [markdown]
# ### Jointure externe left
#
# La jointure externe `left` récupère toutes les informations du DataFrame de gauche et les informations du DataFrame de droite qui sont en commun avec la table de gauche.
#
# Le DataFrame de droite renvoie des valeurs nulles pour les lignes du DataFrame de gauche qui n'a rien en commun avec le DataFrame de droite.
#
# ![image.png](attachment:image.png)
#
# Dans notre cas, on obtient un DataFrame avec tous les `Country Code` présent le DataFrame des PIBs et les `Country Code` du DataFrame des metadonnées en commun.

# %%
# jointure externe left
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                        Yemen         Rep.                           YEM
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %% [markdown]
# ### Jointure externe right
#
# La jointure externe `right` suit la même logique que la jointure externe `left`.
#
# On retourne toutes les données du DataFrame de droite + les données en commun du DataFrame de gauche.
#
# ![image.png](attachment:image.png)
#
# Dans notre cas, on obtient un DataFrame avec tous les `Country Code` présent le DataFrame des metadonnées et les `Country Code` du DataFrame des PIBS en commun.

# %%
# jointure externe right
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 260                       Kosovo          XKX  GDP per capita (current US$)
# 261                          NaN          YEM                           NaN
# 262                 South Africa          ZAF  GDP per capita (current US$)
# 263                       Zambia          ZMB  GDP per capita (current US$)
# 264                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %% [markdown]
# ## FULL JOIN outer
#
# La jointure externe FULL JOIN retourne l'ensemble des données du DataFrame de gauche et de droite.
#
# ![image.png](attachment:image.png)
#
# Dans notre cas, on obtient un DataFrame avec tous les `Country Code` du DataFrame des PIBs et du DataFrame des metadonnées.

# %%
# jointure inner
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 274                          NaN          KOR                           NaN
# 275                          NaN          MAC                           NaN
# 276                          NaN          PRK                           NaN
# 277                          NaN          VEN                           NaN
# 278                          NaN          YEM                           NaN
#
# ...
