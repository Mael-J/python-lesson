# %%
#import pandas
import pandas as pd

# %%
# transformer le fichier .csv en DataFrame, séprarateur ; et décimal ,
df = pd.read_csv('country_gdp_per_capita.csv', sep=';', decimal=',')

# %%
df_test = pd.read_csv('test.csv')

# %%
df.T
# Out:
#                                          0                             1    \
# Country Name                           Aruba   Africa Eastern and Southern
# Country Code                             ABW                           AFE
# Indicator Name  GDP per capita (current US$)  GDP per capita (current US$)
# Indicator Code                NY.GDP.PCAP.CD                NY.GDP.PCAP.CD
# 1960                                     NaN                   141,3859554
# ...                                      ...                           ...
# 2019                             31902.80982                   1507.982881
# 2020                             24008.12782                   1355.805923
# 2021                             29127.75938                   1545.613215
# 2022                             33300.83882                   1644.062829
# 2023                                     NaN                           NaN
#
# ...

# %%
df_stack = df.set_index("Country Code")[["2002", "2003"]].stack().reset_index().rename(columns={"level_1": "Year", 0: "GDP"})

# %%
df_stack.pivot(index = "Country Code", columns = "Year", values = "GDP")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_stack.pivot(index = "Country Code", columns = "Year", values = "GDP")
#
# File c:\python\lib\site-packages\pandas\core\frame.py:7882, in DataFrame.pivot(self, index, columns, values)
#    7877 @Substitution("")
#    7878 @Appender(_shared_docs["pivot"])
#    7879 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7880     from pandas.core.reshape.pivot import pivot
# -> 7882     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\python\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# ...

# %%
df_stack.pivot(index = "Country Code", columns=["level_1"], values=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df_stack.pivot(index = "Country Code", columns=["level_1"], values=0)
#
# File c:\python\lib\site-packages\pandas\core\frame.py:7882, in DataFrame.pivot(self, index, columns, values)
#    7877 @Substitution("")
#    7878 @Appender(_shared_docs["pivot"])
#    7879 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7880     from pandas.core.reshape.pivot import pivot
# -> 7882     return pivot(self, index=index, columns=columns, values=values)
#
# File c:\python\lib\site-packages\pandas\core\reshape\pivot.py:520, in pivot(data, index, columns, values)
#     518     else:
#     519         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 520 return indexed.unstack(columns_listlike)
#
# ...

# %%
df
# Out:
#                     Country Name Country Code                Indicator Name  \
# 0                          Aruba          ABW  GDP per capita (current US$)
# 1    Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 2                    Afghanistan          AFG  GDP per capita (current US$)
# 3     Africa Western and Central          AFW  GDP per capita (current US$)
# 4                         Angola          AGO  GDP per capita (current US$)
# ..                           ...          ...                           ...
# 261                       Kosovo          XKX  GDP per capita (current US$)
# 262                        Yemen         Rep.                           YEM
# 263                 South Africa          ZAF  GDP per capita (current US$)
# 264                       Zambia          ZMB  GDP per capita (current US$)
# 265                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...
